# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline

# %%
# Define Dataset
dataset = [11,12,13,16,17,16,17,13,19,18,15,14,108,15,103,15,17,13,103,100,17]

# %%
sns.histplot(dataset, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# Z_Score
outliers = []

def detect_outliers(data):
    threshold = 2
    mean = np.mean(data)
    std = np.std(data)
    
    for i in data:
        z_score = (i-mean)/std
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers

# %%
detect_outliers(dataset)
# Out:
# [108, 103, 103]

# %% [markdown]
# ### **IQR**
#     1. Sort the Data
#     2. Calculate Q1 and Q3
#     3. IQR(Q3 / Q1)
#     4. Find the Lower Fence( Q1-1.5(IQR) )
#     5. Find the Upper Fence( Q3+1.5(IQR) )

# %%
# IQR

dataset = sorted(dataset)
print(dataset)
# Out:
# [11, 12, 13, 13, 13, 14, 15, 15, 15, 16, 16, 17, 17, 17, 17, 18, 19, 100, 103, 103, 108]

# %%
# Find Q1 and Q3
q1,q3 = np.percentile(dataset,[25,75])
print(q1,q3)
# Out:
# 14.0 18.0

# %%
iqr = q3-q1
print(iqr)
# Out:
# 4.0

# %%
# Find the Lower Fence and Upper Fence
lower_fence = q1 - (1.5*iqr)
upper_fence = q3 + (1.5*iqr)
print(lower_fence)
print(upper_fence)
# Out:
# 8.0
# 24.0

# %%
sns.boxplot(dataset)
# Out:
# <Axes: >
